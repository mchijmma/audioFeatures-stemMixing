# %%
import hypertools as hyp
from datetime import datetime

import numpy as np 
import pandas as pd

from pylab import plot, show, figure, imshow
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.style.use('ggplot')

from __future__ import division

import os

import pickle

from collections import OrderedDict

from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn import preprocessing
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn import svm
from sklearn.tree import DecisionTreeRegressor

# %%
#Constant Variables python
# kGroup = sys.argv[1]
# kInstrument = sys.argv[1]
# kSampleRate = 44100
# kN = 100
# kType = 'mono'
# kFeatures = 1812 #Find a way to not hard-code this.     
# path = './Music/Data/MedleyDB/Features/%s/%s/' % (sys.argv[2], kType)


#Constant Variables Jupyter
kGroup = 'tack piano'
kInstrument = 'tack piano'
kSampleRate = 44100
kN = 100 #Number of features to take into account initially.
kType = 'mono'
kFeatures = 1812 #Find a way to not hard-code this.     

#path = './Music/Data/MedleyDB/Features/no_boot_nw_2000/%s/' % (kType)

path = './Music/Data/MedleyDB/Features/Analysis/'




def dumpPickle(d, name, _path = path):
#  path = './Music/Data/MedleyDB/Features/z_Arrays/%s/' % (kType)

  with open(_path + name, 'wb') as output:
    # Pickle dictionary using protocol 0.
    pickle.dump(d, output)
    
  print '%s Saved' % (name)
  
def loadPickle(name,_path = path):  
#  path = './Music/Data/MedleyDB/Features/z_Arrays/%s/' % (kType)
  # load data from pkl file
  with open(_path + name, "rb") as fp:
      loaded_data1 = pickle.load(fp)
  
  print '%s loaded, %s ' % (name, type(loaded_data1))
  
  return loaded_data1

def plotOOBError(error, xlabel = 'n_features', ylabel = 'OOB error rate'):
    _x = []
    _y = []
    # %matplotlib notebook
    
    for tupla in error:
        _x.append(tupla[0])
        _y.append(tupla[1])
    plt.rcParams['figure.figsize'] = (10,10)    
    plt.plot(_x, _y, 'ko')
    
    plt.xlim(np.min(_x), np.max(_x)+100)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.legend(loc="upper right")
    #plt.show()
    
def plotVTscore(Vscore1, Vstd1, Vscore2, Vstd2, Tscore1, Tscore2, nFeatures, instrument):   

    # %matplotlib notebook
    n_groups = 3

    fig, ax = plt.subplots()

    index = np.arange(n_groups)
    bar_width = 0.1

    opacity = 0.4
    error_config = {'ecolor': '0.3'}

    rects1 = plt.bar(index, Vscore1, bar_width,
                     alpha=opacity*2,
                     color='b',
                     yerr=Vstd1,
                     error_kw=error_config,
                     label='Validation error - %d Features' % nFeatures)

    

    rects3 = plt.bar(index + bar_width, Tscore1, bar_width,
                     alpha=opacity*2,
                     color='r',
                     label='Test error - %d Features' % nFeatures)
    
    rects2 = plt.bar(index + 2*bar_width +0.1, Vscore2, bar_width,
                     alpha=opacity,
                     color='b',
                     yerr=Vstd2,
                     error_kw=error_config,
                     label='Validation error - 3236 Features')

    rects4 = plt.bar(index + 3*bar_width +0.1, Tscore2, bar_width,
                     alpha=opacity,
                     color='r',
                     label='Test error - 3236 Features')

    plt.xlabel('Classifier')
    plt.ylabel('R^2 Score')
    plt.title('R^score Validation and Test - %s' %(instrument))
    plt.xticks(index + 4*bar_width / 2+0.05, ('RF','SV','LG'))
    plt.legend()

    plt.tight_layout()
    #plt.show()

# %%
#%%
#Only if you initialized Variables.

# X = loadPickle('X.pkl')
# y = loadPickle('y.pkl')
# XRaw = loadPickle('XRaw.pkl')
# yRaw = loadPickle('yRaw.pkl')
# XStem = loadPickle('XStem.pkl')
# yStem = loadPickle('yStem.pkl')

# gListTracks = loadPickle('gListTracks.pkl')
# gNameFeatures = loadPickle('gNameFeatures.pkl')


# gImportances = loadPickle('gImportances.pkl')
# gPreSelectedImportances = loadPickle('gPreSelectedImportances.pkl')

# gInterpretationOOBError = loadPickle('gInterpretationOOBError.pkl')
# gInterpretationIdx = loadPickle('gInterpretationIdx.pkl')
# gInterpretationFeatures = loadPickle('gInterpretationFeatures.pkl')

# gPredictionOOBError = loadPickle('gPredictionOOBError.pkl')
# gPredictionIdx = loadPickle('gPredictionIdx.pkl')
# gPredictionOOBErrorGain = loadPickle('gPredictionOOBErrorGain.pkl')

# gPreSelectedFeatures = loadPickle('gPreSelectedFeatures.pkl')
# gPredictionFeatures = loadPickle('gPredictionFeatures.pkl')


X = loadPickle('X.pkl')
y = loadPickle('y.pkl')
gNameFeatures = loadPickle('gNameFeatures.pkl')
gPreSelectedFeatures = loadPickle('gPreSelectedFeatures.pkl')


GInterpretationFeatures= loadPickle('gInterpretationFeatures.pkl', _path = path)
gInterpretationIdx= loadPickle('gInterpretationIdx.pkl', _path = path)
GInterpretationOOBError= loadPickle('gIntepretationOOB.pkl', _path = path)

GPrePredictionOOBError= loadPickle('gPrePredictionOOBError.pkl', _path = path)

GPredictionIdx= loadPickle('gPredictionIdx.pkl', _path = path)
GPredictionOOBError= loadPickle('gPredictionOOBError.pkl', _path = path)
GPredictionOOBErrorGain= loadPickle('gPredictionOOBErrorGain.pkl', _path = path)
# Out:
# X.pkl loaded, <class 'collections.OrderedDict'>
# y.pkl loaded, <class 'collections.OrderedDict'>
# gNameFeatures.pkl loaded, <class 'collections.OrderedDict'>
# gPreSelectedFeatures.pkl loaded, <class 'collections.OrderedDict'>
# gInterpretationFeatures.pkl loaded, <class 'collections.OrderedDict'>
# gInterpretationIdx.pkl loaded, <class 'collections.OrderedDict'>
# gIntepretationOOB.pkl loaded, <class 'collections.OrderedDict'>
# gPrePredictionOOBError.pkl loaded, <class 'collections.OrderedDict'>
# gPredictionIdx.pkl loaded, <class 'collections.OrderedDict'>
# gPredictionOOBError.pkl loaded, <class 'collections.OrderedDict'>
# gPredictionOOBErrorGain.pkl loaded, <class 'collections.OrderedDict'>

# %%
# kInstruments = ['bass1', 'bass2', 'bass3', 'bass4', 'bass5',
#                'guitar1', 'guitar2', 'guitar3', 'guitar4', 'guitar5',
#                'vocal1', 'vocal2', 'vocal3', 'vocal4', 'vocal5',
#                'keys1', 'keys2', 'keys3', 'keys4', 'keys5',
#                'keys-all1', 'keys-all2', 'keys-all3', 'keys-all4', 'keys-all5',
#               ]

kInstruments = ['bass3', 'guitar5', 'vocal2', 'keys-all3']

# %%
#plt.rcParams['figure.figsize'] = (10,10)
# %matplotlib notebook
kGroup = kInstruments[1]

kN = 100

#plt.plot(gImportances[kGroup][0][0:kN], 'k.', gImportances[kGroup][0][0:kN], 'k:',label=kGroup+'_mean' )
#plt.plot(gImportances[kGroup][1][0:kN], 'r.', gImportances[kGroup][1][0:kN], 'r:',label=kGroup+'_std' )

plt.errorbar(np.arange(kN),gImportances[kGroup][0][0:kN], yerr=gImportances[kGroup][1][0:kN]/2, fmt='-o',  markersize=5, color='k', label = 'size 2')
#gImportances.keys()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <Container object of 3 artists>

# %%
plt.rcParams['figure.figsize'] = (14,14)
# %matplotlib notebook

kN = 50

#plt.plot(gImportances[kGroup][0][0:kN], 'k.', gImportances[kGroup][0][0:kN], 'k:',label=kGroup+'_mean' )
#plt.plot(gImportances[kGroup][1][0:kN], 'r.', gImportances[kGroup][1][0:kN], 'r:',label=kGroup+'_std' )
#for kGroup in kInstruments:
opacity = 0.5
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rcParams["axes.facecolor"]= 'w'
#mpl.rcParams["savefig.facecolor"] = '111111'
mpl.rcParams["axes.edgecolor"] = 'k'
mpl.rcParams["savefig.dpi"] = 600
fig = figure()
p1, = plt.plot(gImportances[kInstruments[0]][0][0:kN], 'r:o', alpha = opacity*2)
#p2, = plt.plot(gImportances[kInstruments[0]][0][0:kN], 'k:', alpha = opacity)

p3, = plt.plot(gImportances[kInstruments[1]][0][0:kN], 'b:^', alpha = opacity*2)
#p4, = plt.plot(gImportances[kInstruments[1]][0][0:kN], 'k:', alpha = opacity)

p5, = plt.plot(gImportances[kInstruments[2]][0][0:kN], 'g:s', alpha = opacity*2)
#p6, = plt.plot(gImportances[kInstruments[2]][0][0:kN], 'k:', alpha = opacity)

p7, = plt.plot(gImportances[kInstruments[3]][0][0:kN], 'c:D', alpha = opacity*2)
#p8, = plt.plot(gImportances[kInstruments[3]][0][0:kN], 'k:', alpha = opacity)


# if 'keys' in kGroup:
#         plt.legend([p1],["keys - mean"], fontsize = 26)
# else:
plt.legend([p1,p3,p5,p7],["%s" % kInstruments[0][0:-1],
                          "%s" % kInstruments[1][0:-1],
                          "%s" % kInstruments[2][0:-1],
                          "%s" % kInstruments[3][0:-5]],
           fontsize = 32)

plt.xlabel("feature", fontsize = 32)
plt.ylabel("mean of importance", fontsize = 32)
#plt.axis((-2,kN,0,0.025))
plt.xticks(fontsize = 32)
plt.yticks(fontsize = 32)
fig.savefig('mean.png', format='PNG', transparent = False, dpi=600)
# Out:
# <img src="data:image/png;base64,..." width="1400">

# %%
#plt.rcParams['figure.figsize'] = (10,10)
kGroup = kInstruments
kN = 350
import matplotlib as mpl
mpl.rcParams["axes.facecolor"]= 'w'
mpl.rcParams["axes.edgecolor"] = 'k'
mpl.rcParams["savefig.dpi"] = 600

for kGroup in kInstruments:
    opacity = 0.5
    fig = figure()
    # Create a random dataset
    X_stdTrain = np.arange(0,kN,1).reshape(-1,1)
    y_stdTrain = gImportances[kGroup][1][0:kN][:].reshape(-1,1)

# Fit regression model
    regr_1 = DecisionTreeRegressor(max_depth=3)
    regr_1.fit(X_stdTrain, y_stdTrain)

# # Predict
    X_test = np.arange(0.0, kN, 0.01)[:, np.newaxis]
    y_1 = regr_1.predict(X_test)
    p1, = plt.plot(gImportances[kGroup][1][0:kN], 'k:', alpha = opacity)
    p2, = plt.plot(X_test, y_1, 'b', linewidth=2, alpha = 1)
    threshold = np.min(y_1[y_1>0.0001])
    p3, = plt.plot((0, kN), (threshold, threshold), 'k--', alpha = 1)
    
    if 'keys' in kGroup:
        plt.legend([p1, p2, p3],["std",
                                 "DTR estimation", "threshold"],
                   fontsize = 32)
    else:
        plt.legend([p1, p2, p3],["std",
                                 "DTR estimation", "threshold"],
                   fontsize = 32)
    
    print '\n %s - TH - STD - %f' % (kGroup, threshold)
    
    plt.xlabel("feature", fontsize = 32)
    plt.ylabel("std of importance", fontsize = 32)
    #plt.axis((-2,kN,0,0.010))
    plt.xticks(fontsize = 32)
    plt.yticks(fontsize = 32)
    fig.savefig('%s-std.png'%kGroup, format='PNG', transparent = False, dpi=600)
# Out:
# <img src="data:image/png;base64,..." width="1400">
#  bass3 - TH - STD - 0.000916
# <img src="data:image/png;base64,..." width="1400">
#  guitar5 - TH - STD - 0.000741
# <img src="data:image/png;base64,..." width="1400">
#  vocal2 - TH - STD - 0.000447
# <img src="data:image/png;base64,..." width="1400">
#  keys-all3 - TH - STD - 0.000545

# %%
# LOAD THE RESPECTIVE PRESELECTED FEATURES
#gPreSelectedImportances[kGroup] = gImportances[kGroup][0][gImportances[kGroup][0]>threshold]
len(gInterpretationIdx['keys5'])
# Out:
# 18

# %%
GInterpretationOOBError = OrderedDict()
for k in kInstruments:
    print '\n %s \n' % k.upper()
    
    _A = X[k][:]
    label = y[k]
    XPreSelected = []
    for i in gInterpretationIdx[k]:

        XPreSelected.append(_A[:,i])
    XPreSelected = np.asarray(XPreSelected).T  
    
    startTime = datetime.now() 
  
    oob_error = []
    nEstimators = 2000
    for i in range(len(gInterpretationIdx[k])):
    
        _epoch = 10
        _error = [] 
    
      
        _A = XPreSelected[:,:i+1]
        print _A.shape
    
        forest = RandomForestClassifier(n_estimators=nEstimators,
                                    warm_start=False,
                                    bootstrap = True,
                                    oob_score=True,
                                    max_features=0.3,
                                    random_state=None,
                                    n_jobs = -1)
                                                                    
        for j in range(_epoch):
        
            forest = forest.fit(_A, label)                      
            _error.append(1 - forest.oob_score_)
        
        _error_mean = np.mean(_error, axis = 0) 
        oob_error.append(_error_mean)
      
    
        print 'Batch # %d - OOB error: %f \n' % (i, _error_mean) 
  
    print '\nExecuted in: %s. \n ' % (str(datetime.now() - startTime))
    GInterpretationOOBError[k] = oob_error
# Out:
#  BASS3
#
# (136, 1)
# Batch # 0 - OOB error: 0.551471
#
# (136, 2)
# Batch # 1 - OOB error: 0.464706
#
# (136, 3)
# Batch # 2 - OOB error: 0.304412
#
# (136, 4)
# Batch # 3 - OOB error: 0.277206
#
# (136, 5)
# Batch # 4 - OOB error: 0.276471
#
# (136, 6)
# Batch # 5 - OOB error: 0.260294
#
# (136, 7)
# Batch # 6 - OOB error: 0.283088
#
#
# Executed in: 0:07:35.255049.
#
#
#  GUITAR5
#
# (164, 1)
# Batch # 0 - OOB error: 0.377439
#
# (164, 2)
# Batch # 1 - OOB error: 0.289634
#
# (164, 3)
# Batch # 2 - OOB error: 0.304268
#
# (164, 4)
# Batch # 3 - OOB error: 0.290244
#
# (164, 5)
# Batch # 4 - OOB error: 0.286585
#
# (164, 6)
# Batch # 5 - OOB error: 0.248780
#
# (164, 7)
# Batch # 6 - OOB error: 0.265244
#
# (164, 8)
# Batch # 7 - OOB error: 0.259146
#
# (164, 9)
# Batch # 8 - OOB error: 0.263415
#
# (164, 10)
# Batch # 9 - OOB error: 0.268902
#
# (164, 11)
# Batch # 10 - OOB error: 0.267073
#
# (164, 12)
# Batch # 11 - OOB error: 0.283537
#
# (164, 13)
# ...

# %%
#GInterpretationOOBError = gInterpretationOOBError.copy()
plt.rcParams['figure.figsize'] = (14,14)
kGroup = kInstruments
kN = 25
import matplotlib as mpl
mpl.rcParams["axes.facecolor"]= 'w'
mpl.rcParams["axes.edgecolor"] = 'k'
mpl.rcParams["savefig.dpi"] = 600

#for k in kInstruments:
opacity = 0.5

fig = figure()
p1, = plt.plot(GInterpretationOOBError[kInstruments[0]][0:kN], 'r:o', alpha = opacity*2)
#p2, = plt.plot(gImportances[kInstruments[0]][0][0:kN], 'k:', alpha = opacity)

p3, = plt.plot(GInterpretationOOBError[kInstruments[1]][0:kN], 'b:^', alpha = opacity*2)
#p4, = plt.plot(gImportances[kInstruments[1]][0][0:kN], 'k:', alpha = opacity)

p5, = plt.plot(GInterpretationOOBError[kInstruments[2]][0:kN], 'g:s', alpha = opacity*2)
#p6, = plt.plot(gImportances[kInstruments[2]][0][0:kN], 'k:', alpha = opacity)

p7, = plt.plot(GInterpretationOOBError[kInstruments[3]][0:kN], 'c:D', alpha = opacity*2)
#p8, = plt.plot(gImportances[kInstruments[3]][0][0:kN], 'k:', alpha = opacity)


# if 'keys' in kGroup:
#         plt.legend([p1],["keys - mean"], fontsize = 26)
# else:
plt.legend([p1,p3,p5,p7],["%s" % kInstruments[0][0:-1],
                          "%s" % kInstruments[1][0:-1],
                          "%s" % kInstruments[2][0:-1],
                          "%s" % kInstruments[3][0:-5]],
           fontsize = 32)

plt.xlabel("number of features", fontsize = 32)
plt.ylabel("OOB error", fontsize = 32)
#plt.axis((-2,30,0.15,0.6))
plt.xticks(fontsize = 32)
plt.yticks(fontsize = 32)
plt.grid(True)
fig.savefig('oobI.png', format='PNG', transparent = False, dpi=600)
# Out:
# <img src="data:image/png;base64,..." width="1400">

# %%
GInterpretationFeatures = OrderedDict()
GTHP = OrderedDict()
minIdx = [5,5,6,14,13]

for k,i in zip(kInstruments,minIdx):
    oob_error = GInterpretationOOBError[k]
    print '%s - Real min_oob error at idx: %d\n' % (k,np.argmin(oob_error))
    print '%s - Chosen min_oob error at idx: %d\n' % (k,i)
    
    GInterpretationFeatures[k] = gPreSelectedFeatures[k][:i+1]
    print '\n Interpretation Features: \n'
    for f in GInterpretationFeatures[k]:
        print f
    

    try:
        thresholdP = (1/(len(gPreSelectedFeatures[k])-len(GInterpretationFeatures[k]))) 
        #print thresholdP
        _th = []
        for j in np.arange(len(GInterpretationFeatures[k]),len(gPreSelectedFeatures[k])-1,1):
            _th.append(np.abs(oob_error[j+1] - oob_error[j]))
        thresholdP = thresholdP * np.sum(_th)
        #Delete this, and every k + k.upper().
        if thresholdP == 0.0:
            thresholdP = np.abs(oob_error[-1] - oob_error[-2])
    except:
        thresholdP=0.001
    print '\n THp: %f\n' % thresholdP
    GTHP[k] = thresholdP
# Out:
# bass3 - Real min_oob error at idx: 5
#
# bass3 - Chosen min_oob error at idx: 5
#
#
#  Interpretation Features:
#
# temporal.effective_duration
# tonal.hpcp.dvar2.33
# lowLevel.spectral_energyband_low.mean
# lowLevel.barkbands.max.2
# lowLevel.scvalleys.max.0
# lowLevel.barkbands.stdev.1
#
#  THp: 0.022794
#
# guitar5 - Real min_oob error at idx: 5
#
# guitar5 - Chosen min_oob error at idx: 5
#
#
#  Interpretation Features:
#
# lowLevel.spectral_energyband_middle_low.dvar2
# lowLevel.spectral_energyband_middle_low.max
# dynamic.rms.dvar
# dynamic.loudness.dvar2
# lowLevel.spectral_energyband_middle_low.dmean
# lowLevel.scvalleys.max.0
#
#  THp: 0.004712
#
# vocal2 - Real min_oob error at idx: 12
#
# vocal2 - Chosen min_oob error at idx: 6
#
#
#  Interpretation Features:
#
# lowLevel.sccoeffs.var.1
# lowLevel.sccoeffs.stdev.1
# dynamic.larm.dvar
# lowLevel.scvalleys.dmean2.3
# dynamic.larm.dvar2
# lowLevel.pitch_salience.dmean
# lowLevel.pitch_salience.dmean2
#
#  THp: 0.005952
#
# ...

# %%
#Search one of the interpretation will be the first one.

GPrePredictionOOBError = OrderedDict()

for k in kInstruments:
    print '\n %s \n' % k.upper()
    
        
    _A = X[k][:]
    label = y[k]
    XPreSelected = []
    
    
    for i in gInterpretationIdx[k][0:len(GInterpretationFeatures[k])]:

        XPreSelected.append(_A[:,i])
    XPreSelected = np.asarray(XPreSelected).T  
    
    startTime = datetime.now() 
  
    oob_error = []
    nEstimators = 2000
    for i in range(len(GInterpretationFeatures[k])):
    
        _epoch = 10
        _error = [] 
    
      
        _A = XPreSelected[:,i:i+1]
        print _A.shape
    
        forest = RandomForestClassifier(n_estimators=nEstimators,
                                    warm_start=False,
                                    bootstrap = True,
                                    oob_score=True,
                                    max_features=0.3,
                                    random_state=None,
                                    n_jobs = -1)
                                                                    
        for j in range(_epoch):
        
            forest = forest.fit(_A, label)                      
            _error.append(1 - forest.oob_score_)
        
        _error_mean = np.mean(_error, axis = 0) 
        oob_error.append(_error_mean)
      
    
        print 'Batch # %d - OOB error: %f \n' % (i, _error_mean) 
  
    print '\nExecuted in: %s. \n ' % (str(datetime.now() - startTime))
    GPrePredictionOOBError[k] = oob_error
# Out:
#  BASS3
#
# (136, 1)
# Batch # 0 - OOB error: 0.551471
#
# (136, 1)
# Batch # 1 - OOB error: 0.441176
#
# (136, 1)
# Batch # 2 - OOB error: 0.426471
#
# (136, 1)
# Batch # 3 - OOB error: 0.426471
#
# (136, 1)
# Batch # 4 - OOB error: 0.382353
#
# (136, 1)
# Batch # 5 - OOB error: 0.433824
#
#
# Executed in: 0:09:10.027414.
#
#
#  GUITAR5
#
# (164, 1)
# Batch # 0 - OOB error: 0.377439
#
# (164, 1)
# Batch # 1 - OOB error: 0.402439
#
# (164, 1)
# Batch # 2 - OOB error: 0.346341
#
# (164, 1)
# Batch # 3 - OOB error: 0.347561
#
# (164, 1)
# Batch # 4 - OOB error: 0.463415
#
# (164, 1)
# Batch # 5 - OOB error: 0.475610
#
#
# Executed in: 0:09:00.147247.
#
#
#  VOCAL2
#
# (120, 1)
# Batch # 0 - OOB error: 0.416667
#
# (120, 1)
# Batch # 1 - OOB error: 0.425000
#
# (120, 1)
# Batch # 2 - OOB error: 0.358333
#
# (120, 1)
# Batch # 3 - OOB error: 0.391667
#
# (120, 1)
# Batch # 4 - OOB error: 0.425000
#
# (120, 1)
# Batch # 5 - OOB error: 0.458333
#
# (120, 1)
# ...

# %%
#Re organize idx and feature vectors
GPrePredictionIdx = OrderedDict()
GPreSelectedFeatures = OrderedDict()

for k in kInstruments:
    idxP = []
    prepre = []
    
    oob_error = GPrePredictionOOBError[k]
    print '%s - min_oob error at idx: %d\n' % (k,np.argmin(oob_error))
    idxP.append(gInterpretationIdx[k][np.argmin(oob_error)])
    idx = gInterpretationIdx[k][:]
    del idx[np.argmin(oob_error)]
    for i in idx:
        idxP.append(i)
    GPrePredictionIdx[k] = idxP
    
    prepre.append(gPreSelectedFeatures[k][np.argmin(oob_error)])
    pre = gPreSelectedFeatures[k][:]
    del pre[np.argmin(oob_error)]
    for i in pre:
        prepre.append(i)
    GPreSelectedFeatures[k] = prepre
# Out:
# bass3 - min_oob error at idx: 4
#
# guitar5 - min_oob error at idx: 2
#
# vocal2 - min_oob error at idx: 2
#
# keys-all3 - min_oob error at idx: 13

# %%
startTime = datetime.now() 
 
GPredictionIdx = OrderedDict()
GPredictionOOBError = OrderedDict()
GPredictionOOBErrorGain = OrderedDict()

for k in kInstruments:
    print '\n %s \n' % k.upper()    
    
    idx = GPrePredictionIdx[k][:]
    thresholdP = GTHP[k]
    oob_error = []
    oob_error_total = []
    nEstimators = 2000
    predIdx = idx[:]
    errorGain = []
    _A = X[k][:]
    label = y[k]
    XPreSelected = []
    
    
    for i in gInterpretationIdx[k]:

        XPreSelected.append(_A[:,i])
    XPreSelected = np.asarray(XPreSelected).T  
    
    for i in range(len(idx)):

        _epoch = 10
        _error = [] 

        
        #_A = XPreSelected[:,:i+1]
        if i > 0:
            _A = np.hstack((_A,XPreSelected[:,i].reshape(-1,1)))
        else:
            _A = XPreSelected[:,:i+1]

        print _A.shape

        forest = RandomForestClassifier(n_estimators=nEstimators,
                                        warm_start=False,
                                        bootstrap = True,
                                        oob_score=True,
                                        max_features=0.3,
                                        random_state=None,
                                        n_jobs = -1)

        for j in range(_epoch):

            forest = forest.fit(_A, label)                      
            _error.append(1 - forest.oob_score_)

        _error_mean = np.mean(_error, axis = 0) 
        oob_error.append(_error_mean)
        oob_error_total.append(_error_mean)
        if i > 0:
            _errorGain = oob_error[-2] - oob_error[-1]

            if _errorGain > thresholdP:

                print '\n Feature - %s, Idx - %d - Added' % (GPreSelectedFeatures[k][i],i)

            else:
                _A = np.delete(_A, np.s_[-1], 1)
                predIdx.remove(idx[i])
                del oob_error[-1]

                print '\n Feature - %s, Idx - %d - Eliminated' % (GPreSelectedFeatures[k][i],i)



        else:

            _errorGain = 0
            print '\n Feature - %s, Idx - %d - Added' % (GPreSelectedFeatures[k][i],i)

        #print _errorGain            
        errorGain.append(_errorGain)   



        print '\n Batch # %d - OOB error gain: %f \n' % (i, _errorGain) 
    GPredictionIdx[k] = predIdx
    GPredictionOOBError[k] = oob_error
    GPredictionOOBErrorGain[k] = errorGain
    print '\nExecuted in: %s. \n ' % (str(datetime.now() - startTime))
# Out:
#  BASS3
#
# (136, 1)

# %%
#plt.rcParams['figure.figsize'] = (10,10)
kGroup = kInstruments
kN = 350
import matplotlib as mpl
mpl.rcParams["axes.facecolor"]= 'w'
mpl.rcParams["axes.edgecolor"] = 'k'
mpl.rcParams["savefig.dpi"] = 600

#for k in kInstruments:
opacity = 0.5

fig = figure()
p1, = plt.plot(GPredictionOOBError[kInstruments[0]], 'r:o', alpha = opacity*2)
#p2, = plt.plot(gImportances[kInstruments[0]][0][0:kN], 'k:', alpha = opacity)

p3, = plt.plot(GPredictionOOBError[kInstruments[1]], 'b:^', alpha = opacity*2)
#p4, = plt.plot(gImportances[kInstruments[1]][0][0:kN], 'k:', alpha = opacity)

p5, = plt.plot(GPredictionOOBError[kInstruments[2]], 'g:s', alpha = opacity*2)
#p6, = plt.plot(gImportances[kInstruments[2]][0][0:kN], 'k:', alpha = opacity)

p7, = plt.plot(GPredictionOOBError[kInstruments[3]], 'c:D', alpha = opacity*2)
#p8, = plt.plot(gImportances[kInstruments[3]][0][0:kN], 'k:', alpha = opacity)


# if 'keys' in kGroup:
#         plt.legend([p1],["keys - mean"], fontsize = 26)
# else:
plt.legend([p1,p3,p5,p7],["%s" % kInstruments[0][0:-1],
                          "%s" % kInstruments[1][0:-1],
                          "%s" % kInstruments[2][0:-1],
                          "%s" % kInstruments[3][0:-5]],
           fontsize = 32)

plt.xlabel("number of features", fontsize = 32)
plt.ylabel("OOB error", fontsize = 32)
#plt.axis((-2,kN,0,0.025))
plt.xticks(fontsize = 32)
plt.yticks(fontsize = 32)
plt.grid(True)
fig.savefig('oobP.png', format='PNG', transparent = False, dpi=600)
# Out:
# <img src="data:image/png;base64,..." width="1400">

# %%
def getNameFeaturesIdx(idx, nameFeatures):#, NameFeatures = gNameFeatures):
  a = []
  
  for i in idx:
     
      _a  = (nameFeatures[i])
      #print _a
      a.append(_a)
  
  return a

GPredictionFeatures = OrderedDict()
for k in kInstruments:
    GPredictionFeatures[k] = getNameFeaturesIdx(GPredictionIdx[k], gNameFeatures[k])
    print '\n %s - Prediction Features: \n' % k
    for f in GPredictionFeatures[k]:
        print f
# Out:
#  bass3 - Prediction Features:
#
# lowLevel.scvalleys.max.0
# temporal.effective_duration
# tonal.hpcp.dvar2.33
# lowLevel.spectral_energyband_low.mean
#
#  guitar5 - Prediction Features:
#
# lowLevel.spectral_energy.dvar
# lowLevel.spectral_energyband_middle_low.dvar2
# lowLevel.spectral_energyband_middle_low.dmean
# lowLevel.scvalleys.max.0
# lowLevel.spectral_energyband_middle_low.dmean2
#
#  vocal2 - Prediction Features:
#
# dynamic.larm.dvar
# lowLevel.sccoeffs.stdev.1
# lowLevel.pitch_salience.dmean
# lowLevel.pitch_salience.dmean2
#
#  keys3 - Prediction Features:
#
# dynamic.larm.max
# dynamic.rms.dvar
# temporal.maxDerBeforeMax
# tonal.hpcp.dvar2.29
# lowLevel.spectral_rms.dmean2
#
#  keys-all3 - Prediction Features:
#
# lowLevel.spectral_energyband_middle_low.var
# lowLevel.spectral_energy.max
# lowLevel.spectral_energyband_middle_low.max
# dynamic.loudness_vickers.max
# lowLevel.barkbands.max.5
# rhythm.beats_loudness_band_ratio.dmean2.2

# %%
path = './Music/Data/MedleyDB/Features/Analysis/'
def dumpPickle(d, name, _path = path):
#  path = './Music/Data/MedleyDB/Features/z_Arrays/%s/' % (kType)

  with open(_path + name, 'wb') as output:
    # Pickle dictionary using protocol 0.
    pickle.dump(d, output)
    
  print '%s Saved' % (name)

#dumpPickle(GPredictionFeatures, 'gPredictionFeatures.pkl', _path = path)
#dumpPickle(GPredictionIdx, 'gPredictionIdx.pkl', _path = path)
#dumpPickle(GPredictionOOBError, 'gPredictionOOBError.pkl', _path = path)


path = './Music/Data/MedleyDB/Features/Analysis/'

dumpPickle(GInterpretationFeatures, 'gInterpretationFeatures.pkl', _path = path)
dumpPickle(gInterpretationIdx, 'gInterpretationIdx.pkl', _path = path)
dumpPickle(GInterpretationOOBError, 'gIntepretationOOB.pkl', _path = path)

dumpPickle(X, 'X.pkl', _path = path)
dumpPickle(y, 'y.pkl', _path = path)
dumpPickle(gNameFeatures, 'gNameFeatures.pkl', _path = path)

dumpPickle(gPreSelectedFeatures, 'gPreSelectedFeatures.pkl', _path = path)

dumpPickle(GPrePredictionOOBError, 'gPrePredictionOOBError.pkl', _path = path)
# Out:
# gInterpretationFeatures.pkl Saved
# gInterpretationIdx.pkl Saved
# gIntepretationOOB.pkl Saved
# X.pkl Saved
# y.pkl Saved
# gNameFeatures.pkl Saved
# gPrePredictionOOBError.pkl Saved
